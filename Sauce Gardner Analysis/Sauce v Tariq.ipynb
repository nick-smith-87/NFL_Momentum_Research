# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Sdf = pd.read_csv("./data/Sauce Gardner 2022 - Sheet1.csv")
Tdf = pd.read_csv("./data/Tariq Woolen 2022 - Sheet1.csv")

# %%
Sdf["player"] = "Sauce Gardner"
Tdf["player"] = "Tariq Woolen"
Sdf['Cumulative Yards'] = Sdf['Yards'].cumsum()
Tdf['Cumulative Yards'] = Tdf['Yards'].cumsum()

# %%
combined = pd.concat([Sdf, Tdf])

fig, ax = plt.subplots(figsize=(10,6))
sns.lineplot(data=combined, x="Week", y="Cumulative Yards", hue="player", ax=ax)
ax.set_xlabel("Week")
ax.set_ylabel("Cumulative Yards")
ax.set_title("Yards allowed throughout the season")
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate interception rate for each player
S_interception_rate = Sdf['INTS'].sum() / Sdf['Targets'].sum()
T_interception_rate = Tdf['INTS'].sum() / Tdf['Targets'].sum()

# Calculate completion percentage allowed for each player
S_completion_pct = Sdf['Receptions'] / Sdf['Targets']
T_completion_pct = Tdf['Receptions'] / Tdf['Targets']

# Calculate yards per target allowed for each player
S_yards_per_target = Sdf['Yards'] / Sdf['Targets']
T_yards_per_target = Tdf['Yards'] / Tdf['Targets']

# Create bar chart to compare interception rates
fig, ax = plt.subplots(figsize=(8,6))
ax.bar(['Player 1', 'Player 2'], [S_interception_rate, T_interception_rate])
ax.set_title('Interception Rate Comparison')
ax.set_xlabel('Player')
ax.set_ylabel('Interception Rate')

# Create line chart to compare completion percentages
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(S_completion_pct, label='Player 1')
ax.plot(T_completion_pct, label='Player 2')
ax.set_title('Completion Percentage Comparison')
ax.set_xlabel('Week')
ax.set_ylabel('Completion Percentage')
ax.legend()

# Create line chart to compare yards per target allowed
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(S_yards_per_target, label='Player 1')
ax.plot(T_yards_per_target, label='Player 2')
ax.set_title('Yards per Target Allowed Comparison')
ax.set_xlabel('Week')
ax.set_ylabel('Yards per Target')
ax.legend()

plt.show()

# %%
combined
# Out:
#     Week Opposing Team  Receptions  Yards  YAC  TD  PBU  PEN  Snaps  Targets  \
# 0      1           BLT           1    8.0    5   0    1    0     56        3
# 1      2           CLV           4   33.0    5   1    0    0     62        5
# 2      3           CIN           2   51.0    7   0    2    0     68        4
# 3      4           PIT           2    9.0    6   0    1    0     64        7
# 4      5           MIA           3   26.0   17   0    0    1     67        5
# 5      6            GB           1    8.0    2   0    3    1     65        6
# 6      7           DEN           4   16.0    8   0    3    0     79       10
# 7      8            NE           2   -4.0    2   0    0    0     77        3
# 8      9           BUF           2   59.0    6   0    0    0     62        4
# 9     11            NE           2   19.0   13   0    1    0     63        4
# 10    12           CHI           1   31.0    2   0    0    1     57        3
# 11    13           MIN           2   17.0    2   0    0    1     68        4
# 12    14           BUF           1    8.5    0   0    1    0     59        2
# 13    15           DET           0    6.0    0   0    0    0     68        0
# 14    16           JAX           1   23.0   20   0    0    0     72        2
# 15    17           SEA           3   17.0    7   0    2    0     72        8
# 16    18           MIA           3   42.0    3   0    0    1     55        4
# 0      1           DEN           0    0.0    0   0    0    2     54        3
# 1      2            SF           3   37.0   14   0    0    0     73        4
# 2      3           ATL           3   54.0   19   0    0    0     57        5
# 3      4           DET           3   47.0   12   0    0    3     71        5
# 4      5            NO           2   15.0    9   0    0    1     77        3
# 5      6           ARZ           4   40.0    9   0    0    0     71        7
# 6      7           LAC           3   37.0   14   1    1    0     71        5
# 7      8           NYG           2   48.0   20   0    1    0     65        4
# 8      9           ARZ           2    4.0    0   1    1    0     64        3
# 9     10            TB           4   57.0   31   2    0    0     75        6
# 10    12            LV           1   20.0    3   0    0    0     77        2
# 11    13            LA           1   23.0    7   0    2    0     64        4
# 12    14           CAR           1   18.0    0   0    1    1     73        1
# 13    15            SF           1   54.0   34   1    0    1     64        1
# 14    16            KC           1    6.0    2   0    1    0     53        2
# 15    17           NYJ           5   42.0   17   0    1    0     68        9
# 16    18            LA           2   47.0   16   0    1    0     58        4
#
#           REC%      Y/REC  Longest  Passer Rating  INTS         player  \
# 0     0.333333   8.000000      8.0           42.4     0  Sauce Gardner
# 1     0.800000   8.250000     13.0          133.8     0  Sauce Gardner
# 2     0.500000  25.500000     45.0           95.8     0  Sauce Gardner
# 3     0.285714   4.500000      5.0           39.6     0  Sauce Gardner
# 4     0.600000   8.666667     11.0           34.2     1  Sauce Gardner
# 5     0.166667   8.000000      8.0           39.6     0  Sauce Gardner
# 6     0.400000   4.000000      8.0           47.9     0  Sauce Gardner
# 7     0.666667  -2.000000     -2.0           70.1     0  Sauce Gardner
# 8     0.500000  29.500000     42.0           56.3     1  Sauce Gardner
# 9     0.500000   9.500000     11.0           63.5     0  Sauce Gardner
# 10    0.333333  31.000000     31.0           72.9     0  Sauce Gardner
# 11    0.500000   8.500000     10.0           61.5     0  Sauce Gardner
# 12    0.500000   8.500000      6.0           56.3     0  Sauce Gardner
# 13    0.000000   0.000000      0.0            0.0     0  Sauce Gardner
# 14    0.500000  23.000000     23.0           91.7     0  Sauce Gardner
# 15    0.375000   5.666667     10.0           45.8     0  Sauce Gardner
# 16    0.750000  14.000000     26.0          108.3     0  Sauce Gardner
# 0     0.000000   0.000000      NaN           39.6     0   Tariq Woolen
# 1    75.000000  12.333333     16.0          103.1     0   Tariq Woolen
# 2    60.000000  18.000000     23.0           57.5     1   Tariq Woolen
# 3    60.000000  15.666667     26.0           51.7     1   Tariq Woolen
# 4    66.666667   7.500000     11.0           38.9     1   Tariq Woolen
# 5    57.142857  10.000000     24.0           33.9     1   Tariq Woolen
# 6    60.000000  12.333333     14.0          122.5     0   Tariq Woolen
# 7    50.000000  24.000000     27.0           93.8     0   Tariq Woolen
# 8    66.666667   2.000000      6.0          109.7     0   Tariq Woolen
# 9    66.666667  14.250000     31.0           97.2     1   Tariq Woolen
# 10   50.000000  20.000000     20.0           85.4     0   Tariq Woolen
# 11   25.000000  23.000000     23.0           11.5     1   Tariq Woolen
# 12  100.000000  18.000000     18.0          118.8     0   Tariq Woolen
# 13  100.000000  54.000000     54.0          158.3     0   Tariq Woolen
# 14   50.000000   6.000000      6.0           56.3     0   Tariq Woolen
# 15   55.555556   8.400000     15.0           67.8     0   Tariq Woolen
# 16   50.000000  23.500000     35.0           92.7     0   Tariq Woolen
#
#     Cumulative Yards
# 0                8.0
# 1               41.0
# 2               92.0
# 3              101.0
# 4              127.0
# 5              135.0
# 6              151.0
# 7              147.0
# 8              206.0
# 9              225.0
# 10             256.0
# 11             273.0
# 12             281.5
# 13             287.5
# 14             310.5
# 15             327.5
# 16             369.5
# 0                0.0
# 1               37.0
# 2               91.0
# 3              138.0
# 4              153.0
# 5              193.0
# 6              230.0
# 7              278.0
# 8              282.0
# 9              339.0
# 10             359.0
# 11             382.0
# 12             400.0
# 13             454.0
# 14             460.0
# 15             502.0
# 16             549.0
