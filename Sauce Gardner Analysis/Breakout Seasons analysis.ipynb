# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./data/Breakout Seasons.csv")
data.head(11)
# Out:
#                 Player  Year  Games Played  Receptions  Yards  YAC  TD  PBU  \
# 0        Sauce Gardner  2022            18          34    361  105   1   14
# 1          Josh Norman  2015            20          55    513  124   3   13
# 2      Richard Sherman  2012            17          40    632  135   2   15
# 3         Jalen Ramsey  2017            17          47    586  153   3   12
# 4        Xavien Howard  2020            17          47    695  294   4   10
# 5         J.C. Jackson  2021            18          50    635  230   3   12
# 6   Patrick Surtain II  2022            17          49    560  201   3    8
# 7        Darelle Revis  2009            17          59    748  252   4   11
# 8          Darius Slay  2021            16          44    459  156   3    4
# 9      Stephon Gilmore  2018            17          42    466   83   5   18
# 10       Xavier Rhodes  2016            14          36    429  122   2    3
#
# ...

# %%
no_Sauce = data.drop([0])
no_Sauce
# Out:
#                 Player  Year  Games Played  Receptions  Yards  YAC  TD  PBU  \
# 1          Josh Norman  2015            20          55    513  124   3   13
# 2      Richard Sherman  2012            17          40    632  135   2   15
# 3         Jalen Ramsey  2017            17          47    586  153   3   12
# 4        Xavien Howard  2020            17          47    695  294   4   10
# 5         J.C. Jackson  2021            18          50    635  230   3   12
# 6   Patrick Surtain II  2022            17          49    560  201   3    8
# 7        Darelle Revis  2009            17          59    748  252   4   11
# 8          Darius Slay  2021            16          44    459  156   3    4
# 9      Stephon Gilmore  2018            17          42    466   83   5   18
# 10       Xavier Rhodes  2016            14          36    429  122   2    3
#
#     PEN  Snaps  Targets  REC%  Y/REC  Longest  Passer Rating  INTS
# ...

# %%
no_Sauce.head()
# Out:
#             Player  Year  Games Played  Receptions  Yards  YAC  TD  PBU  PEN  \
# 1      Josh Norman  2015            20          55    513  124   3   13    8
# 2  Richard Sherman  2012            17          40    632  135   2   15    5
# 3     Jalen Ramsey  2017            17          47    586  153   3   12    3
# 4    Xavien Howard  2020            17          47    695  294   4   10    8
# 5     J.C. Jackson  2021            18          50    635  230   3   12    5
#
#    Snaps  Targets  REC%  Y/REC  Longest  Passer Rating  INTS
# 1   1241      108  50.9    9.3       36           58.1     4
# 2    951       86  33.3   15.8       56           40.5     8
# 3    993       92  51.1   12.5       74           63.9     4
# 4    936       90  52.2   14.8       61           53.0    10
# 5    944       98  51.0   12.7       67           47.8     8

# %%
plt.boxplot([no_Sauce.Yards])
plt.title("Breakout Corners Top Year Stats compared to Sauce Gardner")
plt.ylabel("Yards Allowed")
x = 1
y = 361
plt.plot(x, y, marker="o", markersize=10, markeredgecolor="green", markerfacecolor="white")

# %%
mean_scores = no_Sauce.drop(["Player", "Year"], axis = 1)
print("yards: ", mean_scores.Yards.mean())
# Out:
# yards:  572.3

# %%
Sauce_Num = 361
Avg_Num = mean_scores["Yards"].mean()
Avg_Num
#(Sauce_Num - Avg_Num)/Sauce_Num * 100
# Out:
# 572.3
