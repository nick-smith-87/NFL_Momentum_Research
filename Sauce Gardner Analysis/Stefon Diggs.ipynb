# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/Stefon Diggs - Sheet1.csv")

# %%
df
# Out:
#           CB  Receptions  Yards      Y/REC  YAC  TD  PBU  PEN  Snaps  Targets  \
# 0    Sauce 9           2     59  29.500000    6   0    0    0     62        4
# 1   Sauce 14           1      6   6.000000    0   0    1    0     59        2
# 2   Humphrey           3     31  10.333333   -3   0    0    1     63        5
# 3  Alexander           0      0   0.000000    0   0    3    0     58        5
# 4   Peterson           4     46  11.500000   17   0    0    0     75        5
# 5      Jones           2     22  11.000000   12   0    0    2     57        7
#
#        REC%  Longest  Passer Rating  INTS
# 0  0.500000       42           56.3     1
# 1  0.500000        6           56.3     0
# 2  0.600000       17           38.3     1
# 3  0.000000        0            0.0     1
# 4  0.800000       16           65.4     2
# 5  0.285714       13           40.2     0

# %%
import matplotlib.pyplot as plt

# Define the data
players = ['Sauce Week 9', 'Sauce Week 14', 'Humphrey', 'Alexander', 'Peterson', 'Jones']
y_per_rec = [29.5, 6, 10.33, 0, 11.5, 11]
colors = ['green', 'green', 'purple', 'orange', 'purple', 'navy'] 

# Create a bar graph
plt.bar(players, y_per_rec, color = colors)

# Set the title and axis labels
plt.title('Yards per Reception allowed on Stefon Diggs')
plt.xlabel('Player Name')
plt.xticks(rotation=45)
plt.ylabel('Yards per Reception')

# Show the plot
plt.show()
