# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
data = pd.read_csv("Punt_Block_Research - Sheet1 (5).csv")
data
# Out:
#    Date of Game          Game ID Team that blocked Team that was blocked  \
# 0    2017-09-10  2017_01_PIT_CLE               PIT                   CLE
# 1    2017-10-15   2017_06_LA_JAX                LA                   JAX
# 2    2017-10-29  2017_08_IND_CIN               CIN                   IND
# 3       11/5/17   2017_09_LA_NYG                LA                   NYG
# 4       11/5/17    2017_09_TB_NO                NO                    TB
# ..          ...              ...               ...                   ...
# 61     11/28/21  2021_12_CAR_MIA               MIA                   CAR
# 62     12/18/21   2021_15_NE_IND               IND                    NE
# 63     12/26/21  2021_16_WAS_DAL               DAL                   WAS
# 64       1/9/22  2021_18_NYJ_BUF               BUF                   NYJ
# 65      1/22/22    2021_20_SF_GB                SF                    GB
#
#    Home Team  Home Score  Away Score  Home Final Score  Away Final Score  \
# 0        CLE           0           6                18                21
# 1        JAX          14          23                17                27
# 2        CIN           0           0                24                23
# 3        NYG          10          41                17                51
# 4         NO           9           0                30                10
# ..       ...         ...         ...               ...               ...
# 61       MIA           6           0                33                10
# 62       IND          13           0                27                17
# 63       DAL          48           7                56                14
# 64       BUF          10           0                27                10
# 65        GB          10           9                10                13
#
#      Half  location of block  return yards  resulting drive starting location  \
# 0   Half1                 16             0                                NaN
# 1   Half1                 19             8                                NaN
# 2   Half1                 53             0                               53.0
# 3   Half2                 34             0                               34.0
# 4   Half1                 28             7                                NaN
# ..    ...                ...           ...                                ...
# 61  Half1                  9             0                                NaN
# 62  Half1                 32            16                                NaN
# 63  Half2                 10             0                               10.0
# 64  Half1                 45             0                               45.0
# 65  Half2                 12             0                                NaN
#
#     score off return  Score on resulting drive  # of plays on resulting drive  \
# 0                  1                       NaN                              0
# 1                  1                       NaN                              0
# 2                  0                       1.0                              9
# 3                  0                       1.0                              3
# 4                  1                       NaN                              0
# ..               ...                       ...                            ...
# 61                 1                       NaN                              0
# 62                 1                       NaN                              0
# 63                 1                       NaN                              0
# 64                 0                       0.0                              4
# 65                 1                       NaN                              0
#
#     yards on resulting drive  points scored off block/resulting drive  \
# 0                          0                                        6
# 1                          0                                        6
# 2                         38                                        3
# 3                         18                                        6
# 4                          0                                        6
# ..                       ...                                      ...
# 61                         0                                        6
# 62                         0                                        6
# 63                         0                                        6
# 64                         6                                        0
# 65                         0                                        6
#
#     Blocking_team_won  score differential after block (Blocking - Blocked)  \
# 0                   1                                                 -3
# 1                   0                                                  1
# 2                   1                                                  1
# 3                   1                                                  3
# 4                   1                                                 11
# ..                ...                                                ...
# 61                  1                                                 17
# 62                  1                                                 -3
# 63                  1                                                  1
# 64                  1                                                  7
# 65                  1                                                  4
#
#     Points scored by blocking team after block  \
# 0                                           15
# 1                                            4
# 2                                           24
# 3                                           10
# 4                                           21
# ..                                         ...
# 61                                          27
# 62                                          14
# 63                                           8
# 64                                          17
# 65                                           4
#
#     points scored by team that was blocked after block  \
# 0                                                  18
# 1                                                   3
# 2                                                  23
# 3                                                   7
# 4                                                  10
# ..                                                ...
# 61                                                 10
# 62                                                 17
# 63                                                  7
# 64                                                 10
# 65                                                  0
#
#     Blocking Team was winning  Blocking team won  seconds left at punt  \
# 0                           1                  1                  3472
# 1                           1                  1                  1952
# 2                           0                  1                  3288
# 3                           1                  1                  1203
# 4                           1                  1                  3097
# ..                        ...                ...                   ...
# 61                          0                  1                  3258
# 62                          1                  1                  2721
# 63                          1                  1                  1272
# 64                          1                  1                  2722
# 65                          0                  1                   290
#
#     seconds left after drive after punt  \
# 0                                  3472
# 1                                  1952
# 2                                  3041
# 3                                  1108
# 4                                  3097
# ..                                  ...
# 61                                 3258
# 62                                 2721
# 63                                 1272
# 64                                 2610
# 65                                  290
#
#     drives before punt blocked (blocking team)  \
# 0                                            0
# 1                                            8
# 2                                            0
# 3                                            8
# 4                                            1
# ..                                         ...
# 61                                           1
# 62                                           2
# 63                                           8
# 64                                           2
# 65                                           8
#
#     drives after punt (blocking team)  length of drive (seconds)
# 0                                  10                          0
# 1                                   5                          0
# 2                                   9                        247
# 3                                   3                         95
# 4                                   9                          0
# ..                                ...                        ...
# 61                                 10                          0
# 62                                  8                          0
# 63                                  3                          0
# 64                                 12                        112
# 65                                  1                          0
#
# [66 rows x 29 columns]

# %%
blocked_dict = data["Team that was blocked"].value_counts()
blocked_dict
# Out:
# NYG    5
# LAC    5
# CLE    4
# MIN    4
# ATL    4
# GB     3
# NE     3
# DEN    3
# KC     3
# BAL    3
# BUF    3
# CAR    2
# LA     2
# TEN    2
# SF     2
# CHI    2
# JAX    2
# PHI    2
# CIN    2
# TB     2
# IND    2
# MIA    1
# SEA    1
# ARI    1
# DAL    1
# WAS    1
# NYJ    1
# Name: Team that was blocked, dtype: int64

# %%
blocking_dict = data["Team that blocked"].value_counts()
blocking_dict
# Out:
# NE     7
# LA     5
# NO     5
# IND    5
# PIT    4
# MIA    4
# NYJ    4
# ARI    3
# DAL    3
# DET    3
# HOU    3
# PHI    2
# SEA    2
# DEN    2
# CAR    2
# CIN    2
# MIN    1
# KC     1
# NYG    1
# WAS    1
# TB     1
# JAX    1
# ATL    1
# GB     1
# BUF    1
# SF     1
# Name: Team that blocked, dtype: int64

# %%
drive_resulted_in_td = data[data["points scored off block/resulting drive"] == 6]
drive_resulted_in_td = drive_resulted_in_td[drive_resulted_in_td['score off return'] != 1]
pd.set_option('display.max_columns', None)
drive_resulted_in_td['length of drive (seconds)'].describe()
# Out:
# count     23.000000
# mean      54.565217
# std       41.589800
# min        3.000000
# 25%       19.000000
# 50%       57.000000
# 75%       72.000000
# max      155.000000
# Name: length of drive (seconds), dtype: float64

# %%
drive_resulted_in_fg = data[data["points scored off block/resulting drive"] == 3]
pd.set_option('display.max_columns', None)
drive_resulted_in_fg['length of drive (seconds)'].describe()
# Out:
# count      9.000000
# mean     129.666667
# std       50.134818
# min       83.000000
# 25%      100.000000
# 50%      117.000000
# 75%      132.000000
# max      247.000000
# Name: length of drive (seconds), dtype: float64
