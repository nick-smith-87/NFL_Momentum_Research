# %%
import pandas as pd
import numpy as np
import nfl_data_py as nfl
import matplotlib.pyplot as plt

# %%
rushers = pd.read_csv('punt rush counts.csv')
rushers
# Out:
#        season  week  quarter  clock  down  distance  field_position offense  \
# 0        2017     1        3   0:31     4         5             -30     CIN
# 1        2017     1        3   4:10     4         8             -49     DET
# 2        2017     1        4  12:34     4        12             -24     BLT
# 3        2017     1        4  15:00     4        21             -39     PHI
# 4        2017     1        4  10:38     4        10              48     TEN
# ...       ...   ...      ...    ...   ...       ...             ...     ...
# 12066    2022     9        1  10:49     4        11             -17     BLT
# 12067    2022     9        1   8:32     4         1             -31      NO
# 12068    2022     9        2  15:00     4        16             -14      NO
# 12069    2022     9        2  11:53     4         9             -45     BLT
# 12070    2022     9        2   9:14     4         2             -30      NO
#
#       defense  punt_rush_count
# 0         BLT              1.0
# 1         ARZ              NaN
# 2         CIN              NaN
# 3         WAS              NaN
# 4         OAK              NaN
# ...       ...              ...
# 12066      NO              1.0
# 12067     BLT              2.0
# 12068     BLT              NaN
# 12069      NO              1.0
# 12070     BLT              2.0
#
# [12071 rows x 10 columns]

# %%
rushers = rushers[rushers['season'] != 2022]
rushers
# Out:
#        season  week  quarter  clock  down  distance  field_position offense  \
# 0        2017     1        3   0:31     4         5             -30     CIN
# 1        2017     1        3   4:10     4         8             -49     DET
# 2        2017     1        4  12:34     4        12             -24     BLT
# 3        2017     1        4  15:00     4        21             -39     PHI
# 4        2017     1        4  10:38     4        10              48     TEN
# ...       ...   ...      ...    ...   ...       ...             ...     ...
# 11219    2021    18        4   1:34     4         5             -45      LA
# 11220    2021    18        4   4:59     4         3             -28     MIA
# 11221    2021    18        4   7:36     4        15             -20     NYJ
# 11222    2021    18        4   3:20     4        20             -15     NYJ
# 11223    2021    18        4   0:14     4        10              47     MIA
#
#       defense  punt_rush_count
# 0         BLT              1.0
# 1         ARZ              NaN
# 2         CIN              NaN
# 3         WAS              NaN
# 4         OAK              NaN
# ...       ...              ...
# 11219      SF              1.0
# 11220      NE              NaN
# 11221     BUF              4.0
# 11222     BUF              NaN
# 11223      NE              3.0
#
# [10961 rows x 10 columns]

# %%
num_rushers_dict = rushers['punt_rush_count'].value_counts()
num_rushers_dict
# Out:
# 1.0     2482
# 2.0     1065
# 3.0      463
# 4.0      359
# 5.0      336
# 6.0      278
# 8.0      174
# 7.0      174
# 9.0       17
# 10.0       3
# 11.0       1
# Name: punt_rush_count, dtype: int64

# %%
rushers['punt_rush_count'] = rushers['punt_rush_count'].fillna(0)
# Out:
# /var/folders/zg/329ty9ws0hlfcxk3nkfm6s9r0000gn/T/ipykernel_69185/3630387408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rushers['punt_rush_count'] = rushers['punt_rush_count'].fillna(0)

# %%
num_rushers_dict = rushers['punt_rush_count'].value_counts()
num_rushers_dict
# Out:
# 0.0     5609
# 1.0     2482
# 2.0     1065
# 3.0      463
# 4.0      359
# 5.0      336
# 6.0      278
# 8.0      174
# 7.0      174
# 9.0       17
# 10.0       3
# 11.0       1
# Name: punt_rush_count, dtype: int64

# %%
rushers = rushers[rushers['punt_rush_count'] == 10.0]
rushers
# Out:
#        season  week  quarter clock  down  distance  field_position offense  \
# 4979     2019     4        1  6:30     4        14             -33     BUF
# 10235    2021    12        4  0:31     4        12              40     NYJ
# 10285    2021    11        4  0:23     4        16             -46     HST
#
#       defense  punt_rush_count
# 4979       NE             10.0
# 10235     HST             10.0
# 10285     TEN             10.0

# %%
rushers = pd.read_csv('punt rush counts.csv')
rushers = rushers[rushers['season'] != 2022]
rushers['punt_rush_count'] = rushers['punt_rush_count'].fillna(0)
rushers
# Out:
#        season  week  quarter  clock  down  distance  field_position offense  \
# 0        2017     1        3   0:31     4         5             -30     CIN
# 1        2017     1        3   4:10     4         8             -49     DET
# 2        2017     1        4  12:34     4        12             -24     BLT
# 3        2017     1        4  15:00     4        21             -39     PHI
# 4        2017     1        4  10:38     4        10              48     TEN
# ...       ...   ...      ...    ...   ...       ...             ...     ...
# 11219    2021    18        4   1:34     4         5             -45      LA
# 11220    2021    18        4   4:59     4         3             -28     MIA
# 11221    2021    18        4   7:36     4        15             -20     NYJ
# 11222    2021    18        4   3:20     4        20             -15     NYJ
# 11223    2021    18        4   0:14     4        10              47     MIA
#
#       defense  punt_rush_count
# 0         BLT              1.0
# 1         ARZ              0.0
# 2         CIN              0.0
# 3         WAS              0.0
# 4         OAK              0.0
# ...       ...              ...
# 11219      SF              1.0
# 11220      NE              0.0
# 11221     BUF              4.0
# 11222     BUF              0.0
# 11223      NE              3.0
#
# [10961 rows x 10 columns]

# %%
rushers = pd.read_csv('punt rush counts.csv')
rushers = rushers[rushers['season'] != 2022]
rushers['punt_rush_count'] = rushers['punt_rush_count'].fillna(0)
rushers = rushers[rushers["season"] == 2021]
rushers = rushers[rushers["week"] == 18]
rushers = rushers[rushers["defense"] == "BUF"]
rushers
# Out:
#        season  week  quarter  clock  down  distance  field_position offense  \
# 10845    2021    18        1   9:11     4         1             -34     NYJ
# 10849    2021    18        1   0:22     4         6             -45     NYJ
# 10969    2021    18        3  12:44     4         1             -35     NYJ
# 10974    2021    18        3  10:05     4         8             -22     NYJ
# 10980    2021    18        3   6:35     4        18             -24     NYJ
# 11144    2021    18        2  10:17     4        27             -24     NYJ
# 11146    2021    18        2   7:17     4         9             -20     NYJ
# 11158    2021    18        2   1:52     4        15             -39     NYJ
# 11216    2021    18        4  12:45     4        19              -7     NYJ
# 11221    2021    18        4   7:36     4        15             -20     NYJ
# 11222    2021    18        4   3:20     4        20             -15     NYJ
#
#       defense  punt_rush_count
# 10845     BUF              3.0
# 10849     BUF              1.0
# 10969     BUF              0.0
# 10974     BUF              2.0
# 10980     BUF              0.0
# 11144     BUF              1.0
# 11146     BUF              0.0
# 11158     BUF              2.0
# 11216     BUF              5.0
# 11221     BUF              4.0
# 11222     BUF              0.0

# %%
blocked_with_rush = pd.read_csv('Punt_Block_Research_with_rushers - Sheet1.csv')
blocked_with_rush
# Out:
#    Date of Game          Game ID Team that blocked Team that was blocked  \
# 0    2017-09-10  2017_01_PIT_CLE               PIT                   CLE
# 1    2017-10-15   2017_06_LA_JAX                LA                   JAX
# 2    2017-10-29  2017_08_IND_CIN               CIN                   IND
# 3       11/5/17   2017_09_LA_NYG                LA                   NYG
# 4       11/5/17    2017_09_TB_NO                NO                    TB
# ..          ...              ...               ...                   ...
# 61     11/28/21  2021_12_CAR_MIA               MIA                   CAR
# 62     12/18/21   2021_15_NE_IND               IND                    NE
# 63     12/26/21  2021_16_WAS_DAL               DAL                   WAS
# 64       1/9/22  2021_18_NYJ_BUF               BUF                   NYJ
# 65      1/22/22    2021_20_SF_GB                SF                    GB
#
#    Home Team  Home Score  Away Score  Home Final Score  Away Final Score  \
# 0        CLE           0           6                18                21
# 1        JAX          14          23                17                27
# 2        CIN           0           0                24                23
# 3        NYG          10          41                17                51
# 4         NO           9           0                30                10
# ..       ...         ...         ...               ...               ...
# 61       MIA           6           0                33                10
# 62       IND          13           0                27                17
# 63       DAL          48           7                56                14
# 64       BUF          10           0                27                10
# 65        GB          10           9                10                13
#
#      Half  ...  Blocking Team was winning  Blocking team won  \
# 0   Half1  ...                          1                  1
# 1   Half1  ...                          1                  1
# 2   Half1  ...                          0                  1
# 3   Half2  ...                          1                  1
# 4   Half1  ...                          1                  1
# ..    ...  ...                        ...                ...
# 61  Half1  ...                          0                  1
# 62  Half1  ...                          1                  1
# 63  Half2  ...                          1                  1
# 64  Half1  ...                          1                  1
# 65  Half2  ...                          0                  1
#
#     seconds left at punt  seconds left after drive  \
# 0                   3472                      3472
# 1                   1952                      1952
# 2                   3288                      3041
# 3                   1203                      1108
# 4                   3097                      3097
# ..                   ...                       ...
# 61                  3258                      3258
# 62                  2721                      2721
# 63                  1272                      1272
# 64                  2722                      2610
# 65                   290                       290
#
#     drives before punt blocked (blocking team)  \
# 0                                            0
# 1                                            8
# 2                                            0
# 3                                            8
# 4                                            1
# ..                                         ...
# 61                                           1
# 62                                           2
# 63                                           8
# 64                                           2
# 65                                           8
#
#     drives after punt (blocking team)  length of drive (seconds)  \
# 0                                  10                          0
# 1                                   5                          0
# 2                                   9                        247
# 3                                   3                         95
# 4                                   9                          0
# ..                                ...                        ...
# 61                                 10                          0
# 62                                  8                          0
# 63                                  3                          0
# 64                                 12                        112
# 65                                  1                          0
#
#     Sub 32 degrees/15 mph wind?  Degree of Precipitation  number of rushers
# 0                             0                        0                  6
# 1                             0                        0                  7
# 2                             0                        0                  8
# 3                             0                        1                  6
# 4                             0                        0                  1
# ..                          ...                      ...                ...
# 61                            0                        0                  4
# 62                            0                        0                  6
# 63                            0                        0                  1
# 64                            2                        2                  1
# 65                            2                        0                  5
#
# [66 rows x 32 columns]

# %%
rush_data = blocked_with_rush['number of rushers'].value_counts()
rush_data
# Out:
# 2     12
# 1     11
# 6      9
# 5      9
# 8      7
# 7      6
# 3      6
# 4      5
# 10     1
# Name: number of rushers, dtype: int64
