# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df06 = pd.read_csv("./Data/RB Research Data Temp - 2006-2007.csv")
df07 = pd.read_csv("./Data/RB Research Data Temp - 2007-2008.csv")
df08 = pd.read_csv("./Data/RB Research Data Temp - 2008-2009.csv")
df09 = pd.read_csv("./Data/RB Research Data Temp - 2009-2010.csv")
df10 = pd.read_csv("./Data/RB Research Data Temp - 2010-2011.csv")
df11 = pd.read_csv("./Data/RB Research Data Temp - 2011-2012.csv")
df12 = pd.read_csv("./Data/RB Research Data Temp - 2012-2013.csv")
df13 = pd.read_csv("./Data/RB Research Data Temp - 2013-2014.csv")
df14 = pd.read_csv("./Data/RB Research Data Temp - 2014-2015.csv")
df15 = pd.read_csv("./Data/RB Research Data Temp - 2015-2016.csv")
df16 = pd.read_csv("./Data/RB Research Data Temp - 2016-2017.csv")
df17 = pd.read_csv("./Data/RB Research Data Temp - 2017-2018.csv")
df18 = pd.read_csv("./Data/RB Research Data Temp - 2018-2019.csv")
df19 = pd.read_csv("./Data/RB Research Data Temp - 2019-2020.csv")
df20 = pd.read_csv("./Data/RB Research Data Temp - 2020-2021.csv")
df21 = pd.read_csv("./Data/RB Research Data Temp - 2021-2022.csv")
df22 = pd.read_csv("./Data/RB Research Data Temp - 2022-2023.csv")
df = pd.concat([df06, df07, df08, df09, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22])
df = df[df['AAV Adjusted'] != -1]
df = df.dropna(subset=['Team'])
df2 = pd.concat([df15, df16, df17, df18, df19, df20, df21, df22])
df2 = df2[df2['AAV Adjusted'] != -1]
df2 = df2.dropna(subset=['Team'])


#df = df.dropna()
#df = df[df["Games Played"] > 8]
df
# Out:
#                    Team  Year Rookie Contract (Y/N)  Contract Length  \
# 0   Edgerrin James  ARI  2006                     N              4.0
# 1     Warrick Dunn  ATL  2006                     N              3.0
# 2      Jamal Lewis  BAL  2006                     N              3.0
# 3   Willis McGahee  BUF  2006                     Y              5.0
# 4   Deshaun Foster  CAR  2006                     N              3.0
# ..             ...  ...   ...                   ...              ...
# 27             NaN   SF  2022                     N              4.0
# 28             NaN  SEA  2022                     Y              4.0
# 29             NaN   TB  2022                     N              3.0
# 30             NaN  TEN  2022                     N              4.0
# 31             NaN  WAS  2022                     Y              4.0
#
#      Total Pay  Yearly Pay (AAV)  Team Payroll  Player Percentage of Payroll  \
# 0   30000000.0      7.500000e+06     102000000                      0.073529
# 1   12450000.0      4.150000e+06     102000000                      0.040686
# 2   26000000.0      8.666667e+06     102000000                      0.084967
# 3    7053000.0      1.410600e+06     102000000                      0.013829
# 4   14500000.0      4.833333e+06     102000000                      0.047386
# ..         ...               ...           ...                           ...
# 27  64063500.0      1.601588e+07     206082457                      0.077716
# 28   8441581.0      2.110395e+06     215796566                      0.009780
# 29  21000000.0      7.000000e+06     202960773                      0.034489
# 30  50000000.0      1.250000e+07     209793874                      0.059582
# 31   5044908.0      1.261227e+06     207402414                      0.006081
#
#     Games Played  ...  Payroll Adjusted  Extra Contract Data  \
# 0             16  ...       155346000.0                  NaN
# 1             16  ...       155346000.0                  NaN
# 2             17  ...       155346000.0                  NaN
# 3             14  ...       155346000.0                  NaN
# 4             14  ...       155346000.0                  NaN
# ..           ...  ...               ...                  ...
# 27            14  ...       216180497.4                  NaN
# 28            16  ...       226370597.7                  NaN
# 29            17  ...       212905850.9                  NaN
# 30            16  ...       220073773.8                  NaN
# 31            12  ...       217565132.3                  NaN
#
#     Guaranteed Money On Current Deal  Money Spent On RBs This Year  \
# 0                                  0                     9150625.0
# 1                                  0                     4732625.0
# 2                            6000000                    10010334.0
# 3                                  0                     2630267.0
# 4                                  0                     8502500.0
# ..                               ...                           ...
# 27                          38162500                     5900000.0
# 28                           5439040                     5400000.0
# 29                          12000000                    15400000.0
# 30                          25500000                    11300000.0
# 31                            849024                     1800000.0
#
#     Player: Total # of Contracts  Player: # of Years in NFL   GM adjusted  \
# 0                              4                         11  0.000000e+00
# 1                              4                         12  0.000000e+00
# 2                              4                         10  9.138000e+06
# 3                              4                         11  0.000000e+00
# 4                              2                          6  0.000000e+00
# ..                           ...                        ...           ...
# 27                             2                          7  4.003246e+07
# 28                             1                          2  5.705553e+06
# 29                             5                          7  1.258800e+07
# 30                             3                          8  2.674950e+07
# 31                             1                          2  8.906262e+05
#
#     Money spent adjusted          Player Name  Unnamed: 0
# 0            13936401.88                  NaN         NaN
# 1            7207787.875                  NaN         NaN
# 2            15245738.17                  NaN         NaN
# 3            4005896.641                  NaN         NaN
# 4            12949308.01                  NaN         NaN
# ..                   ...                  ...         ...
# 27               6189100  Christian McCaffrey         NaN
# 28               5664600   Kenneth Walker III         NaN
# 29              16154600    Leonard Fournette         NaN
# 30              11853700        Derrick Henry         NaN
# 31               1888200       Brian Robinson         NaN
#
# [542 rows x 48 columns]

# %%
years = df.groupby('Year')['Player: # of Years in NFL'].mean()
contract = df.groupby('Year')['Player: Total # of Contracts'].mean()
rb_years = df.groupby('Year')['Contract Length'].mean()


contract
# Out:
# Year
# 2006    3.870968
# 2007    4.161290
# 2008    4.250000
# 2009    3.875000
# 2010    4.406250
# 2011    4.187500
# 2012    3.968750
# 2013    4.187500
# 2014    4.156250
# 2015    4.343750
# 2016    4.281250
# 2017    4.750000
# 2018    3.937500
# 2019    3.562500
# 2020    3.250000
# 2021    2.562500
# 2022    2.312500
# Name: Player: Total # of Contracts, dtype: float64

# %%
plt.plot(rb_years)

# %%
plt.plot(years)

# %%
plt.plot(contract)

# %%
gm = df2.groupby('Year')['GM adjusted'].mean()
money_spent = df2.groupby('Year')['Money spent adjusted'].mean()
df2['GM AAV'] = df2['GM adjusted'] / df2['Contract Length']

GM_aav = df2.groupby('Year')['GM AAV'].mean()

# %%
plt.plot(gm)

# %%
plt.plot(money_spent)

# %%
plt.plot(GM_aav)
