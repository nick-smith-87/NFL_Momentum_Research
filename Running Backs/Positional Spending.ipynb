# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df15 = pd.read_csv("./Data/Positional Spending - Pos_Spend_15.csv")
df16 = pd.read_csv("./Data/Positional Spending - Pos_Spend_16.csv")
df17 = pd.read_csv("./Data/Positional Spending - Pos_Spend_17.csv")
df18 = pd.read_csv("./Data/Positional Spending - Pos_Spend_18.csv")
df19 = pd.read_csv("./Data/Positional Spending - Pos_Spend_19.csv")
df20 = pd.read_csv("./Data/Positional Spending - Pos_Spend_20.csv")
df21 = pd.read_csv("./Data/Positional Spending - Pos_Spend_21.csv")
df22 = pd.read_csv("./Data/Positional Spending - Pos_Spend_22.csv")

df = pd.concat([df15, df16, df17, df18, df19, df20, df21, df22])
df
# Out:
#                     Teams  Year  Players    QBX    RBX    WRX    TEX    OLX  \
# 0       Arizona Cardinals  2015       52  19.9M   2.4M  15.8M   4.6M  26.3M
# 1         Atlanta Falcons  2015       53  21.3M   2.8M  25.7M   3.4M  19.9M
# 2        Baltimore Ravens  2015       52   3.9M   1.1M   2.7M   2.9M  11.9M
# 3           Buffalo Bills  2015       53   4.1M  12.7M   8.4M   1.0M  15.5M
# 4       Carolina Panthers  2015       53  23.9M  11.6M   6.9M  10.1M  15.7M
# ..                    ...   ...      ...    ...    ...    ...    ...    ...
# 27       Seattle Seahawks  2022       53   5.3M   6.2M  44.0M   4.8M  24.9M
# 28    San Francisco 49ers  2022       53   9.1M  24.5M  30.9M  18.1M  36.7M
# 29   Tampa Bay Buccaneers  2022       53  18.6M  10.7M  55.2M  10.9M  33.6M
# 30       Tennessee Titans  2022       51   2.3M  15.3M  22.8M  11.4M   7.6M
# 31  Washington Commanders  2022       52  35.4M   3.1M  42.8M  10.9M  32.7M
#
#       DLX    LBX  ... QB Adjusted RB Adjusted WR Adjusted  TE Adjusted  \
# 0   19.4M  10.7M  ...     25.7705      3.1080     20.4610       5.9570
# 1   22.1M   9.7M  ...     27.5835      3.6260     33.2815       4.4030
# 2    6.2M  15.8M  ...      5.0505      1.4245      3.4965       3.7555
# 3   44.5M   6.2M  ...      5.3095     16.4465     10.8780       1.2950
# 4   29.7M  25.3M  ...     30.9505     15.0220      8.9355      13.0795
# ..    ...    ...  ...         ...         ...         ...          ...
# 27  32.8M  14.2M  ...      5.5597      6.5038     46.1560       5.0352
# 28  42.0M  34.6M  ...      9.5459     25.7005     32.4141      18.9869
# 29  38.4M  25.1M  ...     19.5114     11.2243     57.9048      11.4341
# 30  16.1M   6.2M  ...      2.4127     16.0497     23.9172      11.9586
# 31  40.3M   3.9M  ...     37.1346      3.2519     44.8972      11.4341
#
#     OL Adjusted  DL Adjusted  LB Adjusted  DB Adjusted  \
# 0       34.0585      25.1230      13.8565      33.9290
# 1       25.7705      28.6195      12.5615      10.2305
# 2       15.4105       8.0290      20.4610      34.9650
# 3       20.0725      57.6275       8.0290      19.2955
# 4       20.3315      38.4615      32.7635      11.9140
# ..          ...          ...          ...          ...
# 27      26.1201      34.4072      14.8958      27.0642
# 28      38.4983      44.0580      36.2954      33.7778
# 29      35.2464      40.2816      26.3299      26.5397
# 30       7.9724      16.8889       6.5038      36.1905
# 31      34.3023      42.2747       4.0911      22.3437
#
#     Special Teams Adjusted  Total Adjusted
# 0                   2.7195       33.372797
# 1                   5.6980       35.720633
# 2                   8.2880        6.540398
# 3                   5.9570        6.875802
# 4                   5.8275       40.080897
# ..                     ...             ...
# 27                  9.0214        5.832125
# 28                  7.8675       10.013649
# 29                  6.6087       20.467459
# 30                  4.7205        2.530922
# 31                  5.7695       38.954195
#
# [256 rows x 33 columns]

# %%
qb_money = df.groupby('Year')['QB Adjusted'].mean()
rb_money = df.groupby('Year')['RB Adjusted'].mean()
wr_money = df.groupby('Year')['WR Adjusted'].mean()
te_money = df.groupby('Year')['TE Adjusted'].mean()
ol_money = df.groupby('Year')['OL Adjusted'].mean()
dl_money = df.groupby('Year')['DL Adjusted'].mean()
lb_money = df.groupby('Year')['LB Adjusted'].mean()
db_money = df.groupby('Year')['DB Adjusted'].mean()
st_money = df.groupby('Year')['Special Teams Adjusted'].mean()

# %%
plt.figure(figsize=(10, 6))

plt.plot(qb_money.index, qb_money, label='QB')
plt.plot(rb_money.index, rb_money, label='RB')
plt.plot(wr_money.index, wr_money, label='WR')
plt.plot(te_money.index, te_money, label='TE')
plt.plot(ol_money.index, ol_money, label='OL')
plt.plot(dl_money.index, dl_money, label='DL')
plt.plot(lb_money.index, lb_money, label='LB')
plt.plot(db_money.index, db_money, label='DB')
plt.plot(st_money.index, st_money, label='Special Teams')

plt.xlabel('Year')
plt.ylabel('Average Adjusted Salary')
plt.title('Average Adjusted Salary by Position Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(qb_money.index, qb_money, label='QB')
plt.plot(rb_money.index, rb_money, label='RB')
plt.plot(wr_money.index, wr_money, label='WR')
plt.plot(te_money.index, te_money, label='TE')
plt.plot(ol_money.index, ol_money, label='OL')
#plt.plot(dl_money.index, dl_money, label='DL')
#plt.plot(lb_money.index, lb_money, label='LB')
#plt.plot(db_money.index, db_money, label='DB')
#plt.plot(st_money.index, st_money, label='Special Teams')

plt.xlabel('Year')
plt.ylabel('Average Adjusted Salary (Millions)')
plt.title('Average Adjusted Salary by Position (2015-2022)')
plt.legend()
plt.grid(True)
plt.show()
